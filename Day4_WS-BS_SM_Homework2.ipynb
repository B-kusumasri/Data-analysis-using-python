# %%
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options   #option-to copy the properties of chrome
from selenium.webdriver.common.by import By             #to access the properties of chrome
from selenium.webdriver.common.keys import Keys         #gives the connection b/w keyboard and browser
from webdriver_manager.chrome import ChromeDriverManager #
import pandas as pd

# %%
#define options and set browser capabilities
options=webdriver.ChromeOptions()

# %%
#Access browser capabilities
browser_name= options.to_capabilities()["browserName"]
print(browser_name)
# Out:
# chrome

# %%
#create WebDriver instance with options
driver=webdriver.Chrome(options=options)

# %%
#Navigate to a website
driver.get('https://www.myntra.com/')

# %%
search=driver.find_element(By.XPATH,".//input[@class='desktop-searchBar']")

# %%
search.send_keys("Smart Watches")

# %%
search.send_keys(Keys.ENTER)

# %%
brand=driver.find_elements(By.XPATH,".//h3[@class='product-brand']")
brands=[i.text for i in brand]
print(brands)
# Out:
# ['CMF by Nothing', 'pebble', 'CMF by Nothing', 'boAt', 'pebble', 'NOISE', 'Titan', 'NOISE', 'Cultsport', 'NOISE', 'Fire-Boltt', 'NOISE', 'Fire-Boltt', 'Timex', 'NOISE', 'CMF by Nothing', 'boAt', 'Fire-Boltt', 'CMF by Nothing', 'JUST CORSECA', 'Fire-Boltt', 'Fastrack', 'NOISE', 'Fastrack', 'Fire-Boltt', 'Fire-Boltt', 'Realme', 'boAt', 'Fire-Boltt', 'Fastrack', 'Fire-Boltt', 'French Connection', 'NOISE', 'NOISE', 'Cultsport', 'Fire-Boltt', 'pebble', 'pebble', 'Fire-Boltt', 'NOISE', 'pebble', 'Fire-Boltt', 'HAMMER', 'boAt', 'NOISE', 'boAt', 'Fire-Boltt', 'boAt', 'NOISE', 'HAMMER']

# %%
prod=driver.find_elements(By.XPATH,".//h4[@class='product-product']")
products=[i.text for i in prod]
print(products)
# Out:
# ['Watch Pro', 'Women 1.27" Smart Watch', 'Watch Pro', 'Unisex Wave Genesis Smartwatch', 'Women 1.27" Smart Watch', 'ColorFit Caliber Smartwatch', 'Smart 3 BT Calling SmartWatch', 'Fit Posh Smartwatch', 'Ace XR 1.43" Smart Watches', 'Mettle EliteEdition Smartwatch', 'Starlight Bluetooth Smartwatch', 'ColorFit Icon 2 Smartwatch', 'Hulk 1.78 inch Smartwatch', 'iConnect Gen+ Smart Watch', 'ColorFit Vision 3 Smartwatch', 'Watch Pro', 'Lunar Connect Ace', 'Hurricane Smartwatch', 'Watch Pro', 'Men Sprinter Pro Smartwatch', 'Supernova Bluetooth SmartWatch', 'FS2 BT Calling Smartwatch', 'Fit Posh Smartwatch', 'Z1 with HD Display Smartwatch', 'Cobra AMOLED Smart Watch', 'Hurricane Smartwatch', 'TechLife Watch S100', 'Storm Plus AMOLED Smart Watch', 'Visionary TWS Smartwatch', 'FS2 BT Calling Smartwatch', 'Eclipse Luxe 1.43" Amoled', 'Unisex Smart Watches', 'NoiseFit Evolve 3 Smartwatch', 'Fit Posh Smartwatch', 'Ace X Luxe 1.96" Smartwatch', 'Eclipse Luxe 1.43" Amoled', 'BT Calling Luxury Smartwatch', 'Hive 1.39" Display Smart Watch', 'Crusader Amoled 1.43BT Calling', 'ColorF
# %%
df=pd.DataFrame(columns=['brands','products','prices'])
df
# Out:
# Empty DataFrame
# Columns: [brands, products, prices]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [brands, products, prices]
# Index: []

# %%
df['brands']=brands
df['products']=products
df['prices']=prices

# %%
df
# Out:
#                brands                        products  \
# 0      CMF by Nothing                       Watch Pro
# 1              pebble         Women 1.27" Smart Watch
# 2      CMF by Nothing                       Watch Pro
# 3                boAt  Unisex Wave Genesis Smartwatch
# 4              pebble         Women 1.27" Smart Watch
# 5               NOISE     ColorFit Caliber Smartwatch
# 6               Titan   Smart 3 BT Calling SmartWatch
# 7               NOISE             Fit Posh Smartwatch
# 8           Cultsport      Ace XR 1.43" Smart Watches
# 9               NOISE  Mettle EliteEdition Smartwatch
# 10         Fire-Boltt  Starlight Bluetooth Smartwatch
# 11              NOISE      ColorFit Icon 2 Smartwatch
# 12         Fire-Boltt       Hulk 1.78 inch Smartwatch
# 13              Timex       iConnect Gen+ Smart Watch
# 14              NOISE    ColorFit Vision 3 Smartwatch
# 15     CMF by Nothing                       Watch Pro
# 16               boAt               Lunar Connect Ace
# 17         Fire-Boltt            Hurricane Smartwatch
# 18     CMF by Nothing                       Watch Pro
# 19       JUST CORSECA     Men Sprinter Pro Smartwatch
# 20         Fire-Boltt  Supernova Bluetooth SmartWatch
# 21           Fastrack       FS2 BT Calling Smartwatch
# 22              NOISE             Fit Posh Smartwatch
# 23           Fastrack   Z1 with HD Display Smartwatch
# 24         Fire-Boltt        Cobra AMOLED Smart Watch
# 25         Fire-Boltt            Hurricane Smartwatch
# 26             Realme             TechLife Watch S100
# 27               boAt   Storm Plus AMOLED Smart Watch
# 28         Fire-Boltt        Visionary TWS Smartwatch
# 29           Fastrack       FS2 BT Calling Smartwatch
# 30         Fire-Boltt       Eclipse Luxe 1.43" Amoled
# 31  French Connection            Unisex Smart Watches
# 32              NOISE    NoiseFit Evolve 3 Smartwatch
# 33              NOISE             Fit Posh Smartwatch
# 34          Cultsport     Ace X Luxe 1.96" Smartwatch
# 35         Fire-Boltt       Eclipse Luxe 1.43" Amoled
# 36             pebble    BT Calling Luxury Smartwatch
# 37             pebble  Hive 1.39" Display Smart Watch
# 38         Fire-Boltt  Crusader Amoled 1.43BT Calling
# 39              NOISE    ColorFit Vision 2 Smartwatch
# 40             pebble          Bold Pro Smart watches
# 41         Fire-Boltt        Cobra AMOLED Smart Watch
# 42             HAMMER    Unisex Pulse 2.0 Smart Watch
# 43               boAt           Lunar Fit Smart Watch
# 44              NOISE        Vision 2 Buzz Smartwatch
# 45               boAt           Lunar Fit Smart Watch
# 46         Fire-Boltt       Hulk 1.78 inch Smartwatch
# 47               boAt  Unisex Wave Genesis Smartwatch
# 48              NOISE    NoiseFit Evolve 4 Smartwatch
# 49             HAMMER   Bluetooth Calling Smart Watch
#
