# %%
import requests
#querystring = {"prompt":"a painting of foxes playing poker, disney, zootopia","batch_size":"1","negative_prompt":"ugly, duplicate, morbid, mutilated, [out of frame], extra fingers, mutated hands, poorly drawn hands, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions"}

RapidAPIKey="84a91cef55mshddc41ba12a286c8p1a4f88jsn565a0afae50c"
RapidAPIHost= "text-to-image7.p.rapidapi.com"
url = f"https://text-to-image7.p.rapidapi.com/v1/current.json?key={RapidAPIKey}&q={RapidAPIHost}"
response = requests.get(url)#params=querystring

data=response.json()
print(data)
# Out:
# {'message': 'Invalid API key. Go to https://docs.rapidapi.com/docs/keys for more info.'}

# %%
import requests

url = "https://text-to-image7.p.rapidapi.com/"

querystring = {"prompt":"a painting of parrots eating poker, disney, zootopia","batch_size":"1","negative_prompt":"ugly, duplicate, morbid, mutilated, [out of frame], extra fingers, mutated hands, poorly drawn hands, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions"}

headers = {
	"X-RapidAPI-Key": "84a91cef55mshddc41ba12a286c8p1a4f88jsn565a0afae50c",
	"X-RapidAPI-Host": "text-to-image7.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': ['https://api.haxed.net/tmp/gCjWtQkALv.png']}
